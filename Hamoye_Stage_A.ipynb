# %% [markdown]
# Question 1:

# %%
y = [(2,4), (7,8), (1,5,9)]
x = y[1][-1]
print(x)
# Out:
# 8

# %%
y = [(2,4), (7,8), (1,5,9)]
x = y[1][1]
print(x)
# Out:
# 8

# %% [markdown]
# Ans: x = y[1][-1]
#
# Ans: x = y[1][1]

# %% [markdown]
# Question 2:

# %% [markdown]
# Ans: 3 features, 100 observations

# %% [markdown]
# Question 3:

# %%
# Importing python libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing dataset

url = 'https://github.com/HamoyeHQ/HDSC-Introduction-to-Python-for-machine-learning/files/7768140/FoodBalanceSheets_E_Africa_NOFLAG.csv'
fbs_data = pd.read_csv(url, encoding= 'latin-1')
fbs_data
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
# The sum of each item per year

fbs_data.groupby(['Item'])[['Y2015','Y2018']].sum()
# Out:
#                          Y2015      Y2018
# Item
# Alcohol, Non-Food      2180.00    2293.00
# Alcoholic Beverages   98783.72   97847.27
# Animal Products       11811.73   11578.61
# Animal fats          200675.72  269648.27
# Apples and products   10559.15    9640.51
# ...                        ...        ...
# Vegetables, Other    158104.08  163987.21
# Vegetal Products     107064.17  107775.39
# Wheat and products   234710.51  242645.19
# Wine                   4251.81    4039.32
# Yams                 203151.78  221272.09
#
# [119 rows x 2 columns]

# %% [markdown]
# Ans: 4251.81 and 4039.32

# %% [markdown]
# Question 4:

# %%
# Mean for whole dataset

fbs_data['Y2017'].mean().round(2)
# Out:
# 140.92

# %%
# Standard Deviation for whole dataset

fbs_data['Y2017'].std().round(2)
# Out:
# 1671.86

# %% [markdown]
# Ans: 140.92 and 1671.86

# %% [markdown]
# Question 5:

# %%
array = np.array([[94,89,63],
                  [93,92,48],
                  [92,94,56]])

array[:2,1:]
# Out:
# array([[89, 63],
#        [92, 48]])

# %% [markdown]
# Ans: array[ : 2, 1 : ]

# %% [markdown]
# Question 6:

# %% [markdown]
# Ans: Dictionary
#
# Ans: Set

# %% [markdown]
# Question 7:

# %%
# Least correlation

fbs_data.corr().sort_values(ascending=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-114-6fa0baf4abb6> in <cell line: 3>()
#       1 # Least correlation
#       2
# ----> 3 fbs_data.corr().sort_values(ascending=False)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in corr(self, method, min_periods, numeric_only)
#   10052         cols = data.columns
#   10053         idx = cols.copy()
# > 10054         mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10055
#   10056         if method == "pearson":
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in to_numpy(self, dtype, copy, na_value)
#    1836         if dtype is not None:
#    1837             dtype = np.dtype(dtype)
# -> 1838         result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839         if result.dtype is not dtype:
# ...

# %% [markdown]
# Ans: 2016

# %% [markdown]
# Question 8:

# %% [markdown]
# Ans: Math

# %% [markdown]
# Question 9:

# %%
fbs_data['Area'].nunique()
# Out:
# 49

# %% [markdown]
# Ans: 49

# %% [markdown]
# Question 10:

# %%
my_tuppy = (1,2,5,8)
my_tuppy[2] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-92-0db9a3bcde61> in <cell line: 2>()
#       1 my_tuppy = (1,2,5,8)
# ----> 2 my_tuppy[2] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# Ans: Type Error

# %% [markdown]
# Question 11:

# %%
fbs_data.groupby('Element')[['Y2017']].sum()
# Out:
#                                              Y2017
# Element
# Domestic supply quantity                2088198.10
# Export Quantity                          182338.80
# Fat supply quantity (g/capita/day)        10253.84
# Feed                                     223705.68
# Food                                    1258888.28
# Food supply (kcal/capita/day)            454681.00
# Food supply quantity (kg/capita/yr)       48690.04
# Import Quantity                          294559.09
# Losses                                   160614.00
# Other uses (non-food)                     91645.97
# Processing                               292836.00
# Production                              2030056.89
# Protein supply quantity (g/capita/day)    11842.45
# Residuals                                 35500.00
# Seed                                      24870.14
# Stock Variation                           54316.91
# Total Population - Both sexes           1112641.00
# ...

# %% [markdown]
# Ans: 292836.00

# %% [markdown]
# Question 12:

# %%
# Total number and Percentage of missing data

total = fbs_data.isnull().sum().sort_values(ascending=False)
percent1 = fbs_data.isnull().sum()/fbs_data.isnull().count()*100
percent2 = (round(percent1, 3)).sort_values(ascending=False)
missing_data = pd.concat([total, percent2], axis=1, keys=['Total', '%'])
missing_data.head()
# Out:
#        Total      %
# Y2014   1589  2.607
# Y2015   1548  2.540
# Y2016   1535  2.519
# Y2017   1506  2.471
# Y2018   1436  2.356

# %% [markdown]
# Ans: 1589 and 2.607%

# %% [markdown]
# Question 13:

# %% [markdown]
# Ans:

# %% [markdown]
# Question 14:

# %%
S = [['him', 'sell'], [90, 28, 43]]

S[0][1][1]
# Out:
# 'e'

# %% [markdown]
# Ans: 'e'

# %% [markdown]
# Question 15:

# %% [markdown]
# Ans: df.shape

# %% [markdown]
# Question 16:

# %%
fbs_data.groupby('Area')[['Y2017']].sum().sort_values(by='Y2017', ascending=True)
# Out:
#                                   Y2017
# Area
# Sudan (former)                     0.00
# Ethiopia PDR                       0.00
# Comoros                           59.84
# Seychelles                       442.34
# Sao Tome and Principe          12662.63
# Cabo Verde                     14650.74
# Guinea-Bissau                  19102.77
# Lesotho                        21267.96
# Botswana                       22101.30
# Djibouti                       22729.91
# Gambia                         23154.18
# Gabon                          27979.64
# Liberia                        29342.20
# Namibia                        29874.89
# Central African Republic       29937.00
# Congo                          41181.68
# Togo                           49841.88
# Mauritius                      51114.83
# Eswatini                       54343.33
# Sierra Leone                   55311.33
# Chad                           71594.68
# Rwanda                         73663.69
# ...

# %% [markdown]
# Ans: Guinea-Bissau

# %% [markdown]
# Question 17:

# %% [markdown]
# Ans:

# %% [markdown]
# Question 18:

# %%
lst = [[35,'Portugal',94],[33,'Argentina',93],[30,'Brazil',92]]

col = ['Age','Nationality','Overall']

df = pd.DataFrame(lst, columns = col, index=[1,2,3])

df
# Out:
#    Age Nationality  Overall
# 1   35    Portugal       94
# 2   33   Argentina       93
# 3   30      Brazil       92

# %% [markdown]
# Ans: None of the above

# %% [markdown]
# Question 19:

# %%
fbs_data.groupby('Area')[['Y2017']].sum().sort_values(by='Y2017', ascending=False)
# Out:
#                                   Y2017
# Area
# Nigeria                      1483268.23
# Egypt                         866379.92
# South Africa                  517590.54
# Ethiopia                      448683.76
# Morocco                       388495.36
# Ghana                         337599.06
# Algeria                       325644.27
# United Republic of Tanzania   322616.85
# Kenya                         264660.66
# Sudan                         239931.92
# Cameroon                      232030.43
# Angola                        229159.57
# Côte d'Ivoire                 224599.01
# Uganda                        213950.38
# Malawi                        181098.71
# Mozambique                    161407.98
# Mauritania                    156665.46
# Mali                          149928.33
# Madagascar                    131197.73
# Niger                         126707.58
# Benin                         124771.22
# Tunisia                       124167.20
# ...

# %% [markdown]
# Ans: Nigeria

# %% [markdown]
# Question 20:

# %% [markdown]
# Ans: c and d
